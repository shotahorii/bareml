# %%
import gym
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
from IPython import display

from bareml.machinelearning.reinforcement import QLearning

# %%
env = gym.make('CartPole-v0') # https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py
max_episodes = 2000
max_timesteps = 200

# %%
# data transform utils

def bins(clip_min, clip_max, num):
    return np.linspace(clip_min, clip_max, num + 1)[1:-1]

def digitize_state(observation):
    num_dizitized = 6 # number of chunks to divide the data into
    cart_pos, cart_v, pole_angle, pole_v = observation
    digitized = [
        np.digitize(cart_pos, bins=bins(-2.4, 2.4, num_dizitized)),
        np.digitize(cart_v, bins=bins(-3.0, 3.0, num_dizitized)),
        np.digitize(pole_angle, bins=bins(-0.5, 0.5, num_dizitized)),
        np.digitize(pole_v, bins=bins(-2.0, 2.0, num_dizitized))
    ]
    return sum([x * (num_dizitized**i) for i, x in enumerate(digitized)])

# %%
q = QLearning(6**4, 2)

past_rewards = []
is_satisfied = False
imgs = []

for episode in range(max_episodes):
    # init environment 
    observation = env.reset()
    # encode state
    state = digitize_state(observation)
    episode_reward = 0

    for t in range(max_timesteps):
        
        # save rendering images when the exit criteria is met
        if is_satisfied:
            imgs.append(env.render(mode="rgb_array"))
            
        # decide action to take, based on the current state
        action = q.action(state, episode)
        # observe the new state of environment, based on the action
        observation, reward, done, info = env.step(action)
        # add penalty
        if done and t < 195:
            reward = -200
        # update state
        prev_state = state
        state = digitize_state(observation)
        # update q table 
        q.update(prev_state, action, reward, state)
        # add cumurative reward 
        episode_reward += reward

        if done:
            break 

    past_rewards.append(episode_reward)
    print('Episode %d: %d steps | Avg rewards in recent 100 ep: %f' %
                  (episode, t + 1, sum(past_rewards[-100:])/len(past_rewards[-100:])))
    
    if is_satisfied:
        np.save('gym_imgs.npy', np.array(imgs))
        break
    
    if len(past_rewards) >= 100 and sum(past_rewards[-100:]) >= 19500:
        print('Success in episode %d' % episode)
        is_satisfied = True
# Out:
# Episode 0: 12 steps | Avg rewards in recent 100 ep: -189.000000
# Episode 1: 16 steps | Avg rewards in recent 100 ep: -187.000000
# Episode 2: 65 steps | Avg rewards in recent 100 ep: -170.000000
# Episode 3: 21 steps | Avg rewards in recent 100 ep: -172.500000
# Episode 4: 16 steps | Avg rewards in recent 100 ep: -175.000000
# Episode 5: 16 steps | Avg rewards in recent 100 ep: -176.666667
# Episode 6: 12 steps | Avg rewards in recent 100 ep: -178.428571
# Episode 7: 43 steps | Avg rewards in recent 100 ep: -175.875000
# Episode 8: 28 steps | Avg rewards in recent 100 ep: -175.555556
# Episode 9: 26 steps | Avg rewards in recent 100 ep: -175.500000
# Episode 10: 21 steps | Avg rewards in recent 100 ep: -175.909091
# Episode 11: 25 steps | Avg rewards in recent 100 ep: -175.916667
# Episode 12: 63 steps | Avg rewards in recent 100 ep: -173.000000
# Episode 13: 29 steps | Avg rewards in recent 100 ep: -172.928571
# Episode 14: 92 steps | Avg rewards in recent 100 ep: -168.666667
# Episode 15: 84 steps | Avg rewards in recent 100 ep: -165.437500
# Episode 16: 47 steps | Avg rewards in recent 100 ep: -164.764706
# Episode 17: 21 steps | Avg rewards in recent 100 ep: -165.611111
# Episode 18: 200 steps | Avg rewards in recent 100 ep: -146.368421
# Episode 19: 27 steps | Avg rewards in recent 100 ep: -147.750000
# Episode 20: 200 steps | Avg rewards in recent 100 ep: -131.190476
# Episode 21: 200 steps | Avg rewards in recent 100 ep: -116.136364
# Episode 22: 200 steps | Avg rewards in recent 100 ep: -102.391304
# Episode 23: 181 steps | Avg rewards in recent 100 ep: -98.958333
# Episode 24: 42 steps | Avg rewards in recent 100 ep: -101.360000
# Episode 25: 95 steps | Avg rewards in recent 100 ep: -101.538462
# Episode 26: 62 steps | Avg rewards in recent 100 ep: -102.925926
# Episode 27: 110 steps | Avg rewards in recent 100 ep: -102.500000
# Episode 28: 181 steps | Avg rewards in recent 100 ep: -99.655172
# Episode 29: 17 steps | Avg rewards in recent 100 ep: -102.466667
# Episode 30: 200 steps | Avg rewards in recent 100 ep: -92.709677
# Episode 31: 147 steps | Avg rewards in recent 100 ep: -91.500000
# Episode 32: 160 steps | Avg rewards in recent 100 ep: -89.969697
# Episode 33: 183 steps | Avg rewards in recent 100 ep: -87.852941
# Episode 34: 200 steps | Avg rewards in recent 100 ep: -79.628571
# Episode 35: 200 steps | Avg rewards in recent 100 ep: -71.861111
# Episode 36: 46 steps | Avg rewards in recent 100 ep: -74.108108
# Episode 37: 86 steps | Avg rewards in recent 100 ep: -75.184211
# Episode 38: 115 steps | Avg rewards in recent 100 ep: -75.461538
# Episode 39: 35 steps | Avg rewards in recent 100 ep: -77.725000
# Episode 40: 139 steps | Avg rewards in recent 100 ep: -77.341463
# Episode 41: 58 steps | Avg rewards in recent 100 ep: -78.904762
# Episode 42: 129 steps | Avg rewards in recent 100 ep: -78.744186
# Episode 43: 190 steps | Avg rewards in recent 100 ep: -77.204545
# Episode 44: 33 steps | Avg rewards in recent 100 ep: -79.222222
# Episode 45: 171 steps | Avg rewards in recent 100 ep: -78.152174
# Episode 46: 200 steps | Avg rewards in recent 100 ep: -72.234043
# Episode 47: 200 steps | Avg rewards in recent 100 ep: -66.562500
# Episode 48: 200 steps | Avg rewards in recent 100 ep: -61.122449
# Episode 49: 141 steps | Avg rewards in recent 100 ep: -61.100000
# Episode 50: 100 steps | Avg rewards in recent 100 ep: -61.882353
# Episode 51: 200 steps | Avg rewards in recent 100 ep: -56.846154
# Episode 52: 87 steps | Avg rewards in recent 100 ep: -57.924528
# Episode 53: 176 steps | Avg rewards in recent 100 ep: -57.314815
# Episode 54: 200 steps | Avg rewards in recent 100 ep: -52.636364
# Episode 55: 200 steps | Avg rewards in recent 100 ep: -48.125000
# Episode 56: 200 steps | Avg rewards in recent 100 ep: -43.771930
# Episode 57: 200 steps | Avg rewards in recent 100 ep: -39.568966
# Episode 58: 157 steps | Avg rewards in recent 100 ep: -39.644068
# Episode 59: 200 steps | Avg rewards in recent 100 ep: -35.650000
# Episode 60: 135 steps | Avg rewards in recent 100 ep: -36.147541
# Episode 61: 200 steps | Avg rewards in recent 100 ep: -32.338710
# Episode 62: 200 steps | Avg rewards in recent 100 ep: -28.650794
# Episode 63: 200 steps | Avg rewards in recent 100 ep: -25.078125
# Episode 64: 94 steps | Avg rewards in recent 100 ep: -26.338462
# Episode 65: 133 steps | Avg rewards in recent 100 ep: -26.969697
# Episode 66: 200 steps | Avg rewards in recent 100 ep: -23.582090
# Episode 67: 200 steps | Avg rewards in recent 100 ep: -20.294118
# Episode 68: 168 steps | Avg rewards in recent 100 ep: -20.478261
# Episode 69: 190 steps | Avg rewards in recent 100 ep: -20.342857
# Episode 70: 121 steps | Avg rewards in recent 100 ep: -21.183099
# Episode 71: 116 steps | Avg rewards in recent 100 ep: -22.069444
# Episode 72: 55 steps | Avg rewards in recent 100 ep: -23.767123
# Episode 73: 200 steps | Avg rewards in recent 100 ep: -20.743243
# Episode 74: 112 steps | Avg rewards in recent 100 ep: -21.653333
# Episode 75: 21 steps | Avg rewards in recent 100 ep: -23.736842
# Episode 76: 200 steps | Avg rewards in recent 100 ep: -20.831169
# Episode 77: 115 steps | Avg rewards in recent 100 ep: -21.666667
# Episode 78: 140 steps | Avg rewards in recent 100 ep: -22.164557
# Episode 79: 140 steps | Avg rewards in recent 100 ep: -22.650000
# Episode 80: 116 steps | Avg rewards in recent 100 ep: -23.419753
# Episode 81: 120 steps | Avg rewards in recent 100 ep: -24.121951
# Episode 82: 151 steps | Avg rewards in recent 100 ep: -24.433735
# Episode 83: 200 steps | Avg rewards in recent 100 ep: -21.761905
# Episode 84: 140 steps | Avg rewards in recent 100 ep: -22.223529
# Episode 85: 200 steps | Avg rewards in recent 100 ep: -19.639535
# Episode 86: 141 steps | Avg rewards in recent 100 ep: -20.103448
# Episode 87: 151 steps | Avg rewards in recent 100 ep: -20.443182
# Episode 88: 200 steps | Avg rewards in recent 100 ep: -17.966292
# Episode 89: 105 steps | Avg rewards in recent 100 ep: -18.833333
# Episode 90: 137 steps | Avg rewards in recent 100 ep: -19.329670
# Episode 91: 200 steps | Avg rewards in recent 100 ep: -16.945652
# Episode 92: 164 steps | Avg rewards in recent 100 ep: -17.161290
# Episode 93: 200 steps | Avg rewards in recent 100 ep: -14.851064
# Episode 94: 27 steps | Avg rewards in recent 100 ep: -16.526316
# Episode 95: 21 steps | Avg rewards in recent 100 ep: -18.229167
# Episode 96: 55 steps | Avg rewards in recent 100 ep: -19.546392
# Episode 97: 53 steps | Avg rewards in recent 100 ep: -20.857143
# Episode 98: 127 steps | Avg rewards in recent 100 ep: -21.393939
# Episode 99: 137 steps | Avg rewards in recent 100 ep: -21.820000
# Episode 100: 200 steps | Avg rewards in recent 100 ep: -17.930000
# Episode 101: 200 steps | Avg rewards in recent 100 ep: -14.080000
# Episode 102: 192 steps | Avg rewards in recent 100 ep: -12.810000
# Episode 103: 114 steps | Avg rewards in recent 100 ep: -11.880000
# Episode 104: 110 steps | Avg rewards in recent 100 ep: -10.940000
# Episode 105: 102 steps | Avg rewards in recent 100 ep: -10.080000
# Episode 106: 86 steps | Avg rewards in recent 100 ep: -9.340000
# Episode 107: 116 steps | Avg rewards in recent 100 ep: -8.610000
# Episode 108: 45 steps | Avg rewards in recent 100 ep: -8.440000
# Episode 109: 113 steps | Avg rewards in recent 100 ep: -7.570000
# Episode 110: 45 steps | Avg rewards in recent 100 ep: -7.330000
# Episode 111: 132 steps | Avg rewards in recent 100 ep: -6.260000
# Episode 112: 104 steps | Avg rewards in recent 100 ep: -5.850000
# Episode 113: 87 steps | Avg rewards in recent 100 ep: -5.270000
# Episode 114: 137 steps | Avg rewards in recent 100 ep: -4.820000
# Episode 115: 136 steps | Avg rewards in recent 100 ep: -4.300000
# Episode 116: 110 steps | Avg rewards in recent 100 ep: -3.670000
# Episode 117: 133 steps | Avg rewards in recent 100 ep: -2.550000
# Episode 118: 172 steps | Avg rewards in recent 100 ep: -4.840000
# Episode 119: 112 steps | Avg rewards in recent 100 ep: -3.990000
# Episode 120: 94 steps | Avg rewards in recent 100 ep: -7.060000
# Episode 121: 129 steps | Avg rewards in recent 100 ep: -9.780000
# Episode 122: 129 steps | Avg rewards in recent 100 ep: -12.500000
# Episode 123: 119 steps | Avg rewards in recent 100 ep: -13.120000
# Episode 124: 193 steps | Avg rewards in recent 100 ep: -11.610000
# Episode 125: 200 steps | Avg rewards in recent 100 ep: -8.550000
# Episode 126: 124 steps | Avg rewards in recent 100 ep: -7.930000
# Episode 127: 200 steps | Avg rewards in recent 100 ep: -5.020000
# Episode 128: 200 steps | Avg rewards in recent 100 ep: -2.820000
# Episode 129: 54 steps | Avg rewards in recent 100 ep: -2.450000
# Episode 130: 200 steps | Avg rewards in recent 100 ep: -2.450000
# Episode 131: 200 steps | Avg rewards in recent 100 ep: 0.090000
# Episode 132: 200 steps | Avg rewards in recent 100 ep: 2.500000
# Episode 133: 196 steps | Avg rewards in recent 100 ep: 4.640000
# Episode 134: 200 steps | Avg rewards in recent 100 ep: 4.640000
# Episode 135: 173 steps | Avg rewards in recent 100 ep: 2.360000
# Episode 136: 200 steps | Avg rewards in recent 100 ep: 5.910000
# Episode 137: 200 steps | Avg rewards in recent 100 ep: 9.060000
# Episode 138: 200 steps | Avg rewards in recent 100 ep: 11.920000
# Episode 139: 40 steps | Avg rewards in recent 100 ep: 11.970000
# Episode 140: 200 steps | Avg rewards in recent 100 ep: 14.590000
# Episode 141: 200 steps | Avg rewards in recent 100 ep: 18.020000
# Episode 142: 200 steps | Avg rewards in recent 100 ep: 20.740000
# Episode 143: 200 steps | Avg rewards in recent 100 ep: 22.850000
# Episode 144: 200 steps | Avg rewards in recent 100 ep: 26.530000
# Episode 145: 200 steps | Avg rewards in recent 100 ep: 28.830000
# Episode 146: 46 steps | Avg rewards in recent 100 ep: 25.280000
# Episode 147: 200 steps | Avg rewards in recent 100 ep: 25.280000
# Episode 148: 200 steps | Avg rewards in recent 100 ep: 25.280000
# Episode 149: 200 steps | Avg rewards in recent 100 ep: 27.880000
# Episode 150: 200 steps | Avg rewards in recent 100 ep: 30.890000
# Episode 151: 200 steps | Avg rewards in recent 100 ep: 30.890000
# Episode 152: 200 steps | Avg rewards in recent 100 ep: 34.030000
# Episode 153: 200 steps | Avg rewards in recent 100 ep: 36.280000
# Episode 154: 200 steps | Avg rewards in recent 100 ep: 36.280000
# Episode 155: 200 steps | Avg rewards in recent 100 ep: 36.280000
# Episode 156: 200 steps | Avg rewards in recent 100 ep: 36.280000
# Episode 157: 200 steps | Avg rewards in recent 100 ep: 36.280000
# Episode 158: 200 steps | Avg rewards in recent 100 ep: 38.720000
# Episode 159: 200 steps | Avg rewards in recent 100 ep: 38.720000
# Episode 160: 200 steps | Avg rewards in recent 100 ep: 41.380000
# Episode 161: 200 steps | Avg rewards in recent 100 ep: 41.380000
# Episode 162: 200 steps | Avg rewards in recent 100 ep: 41.380000
# Episode 163: 200 steps | Avg rewards in recent 100 ep: 41.380000
# Episode 164: 200 steps | Avg rewards in recent 100 ep: 44.450000
# Episode 165: 200 steps | Avg rewards in recent 100 ep: 47.130000
# Episode 166: 200 steps | Avg rewards in recent 100 ep: 47.130000
# Episode 167: 200 steps | Avg rewards in recent 100 ep: 47.130000
# Episode 168: 200 steps | Avg rewards in recent 100 ep: 49.460000
# Episode 169: 200 steps | Avg rewards in recent 100 ep: 51.570000
# Episode 170: 200 steps | Avg rewards in recent 100 ep: 54.370000
# Episode 171: 200 steps | Avg rewards in recent 100 ep: 57.220000
# Episode 172: 200 steps | Avg rewards in recent 100 ep: 60.680000
# Episode 173: 173 steps | Avg rewards in recent 100 ep: 58.400000
# Episode 174: 200 steps | Avg rewards in recent 100 ep: 61.290000
# Episode 175: 200 steps | Avg rewards in recent 100 ep: 65.090000
# Episode 176: 166 steps | Avg rewards in recent 100 ep: 62.740000
# Episode 177: 200 steps | Avg rewards in recent 100 ep: 65.600000
# Episode 178: 200 steps | Avg rewards in recent 100 ep: 68.210000
# Episode 179: 200 steps | Avg rewards in recent 100 ep: 70.820000
# Episode 180: 151 steps | Avg rewards in recent 100 ep: 71.170000
# Episode 181: 200 steps | Avg rewards in recent 100 ep: 73.980000
# Episode 182: 183 steps | Avg rewards in recent 100 ep: 74.300000
# Episode 183: 200 steps | Avg rewards in recent 100 ep: 74.300000
# Episode 184: 200 steps | Avg rewards in recent 100 ep: 76.910000
# Episode 185: 200 steps | Avg rewards in recent 100 ep: 76.910000
# Episode 186: 200 steps | Avg rewards in recent 100 ep: 79.510000
# Episode 187: 200 steps | Avg rewards in recent 100 ep: 82.010000
# Episode 188: 200 steps | Avg rewards in recent 100 ep: 82.010000
# Episode 189: 193 steps | Avg rewards in recent 100 ep: 82.890000
# Episode 190: 200 steps | Avg rewards in recent 100 ep: 85.530000
# Episode 191: 200 steps | Avg rewards in recent 100 ep: 85.530000
# Episode 192: 200 steps | Avg rewards in recent 100 ep: 87.900000
# Episode 193: 125 steps | Avg rewards in recent 100 ep: 85.140000
# Episode 194: 200 steps | Avg rewards in recent 100 ep: 88.880000
# Episode 195: 170 steps | Avg rewards in recent 100 ep: 90.370000
# Episode 196: 200 steps | Avg rewards in recent 100 ep: 93.830000
# Episode 197: 200 steps | Avg rewards in recent 100 ep: 97.310000
# Episode 198: 200 steps | Avg rewards in recent 100 ep: 100.050000
# Episode 199: 192 steps | Avg rewards in recent 100 ep: 100.600000
# Episode 200: 200 steps | Avg rewards in recent 100 ep: 100.600000
# Episode 201: 200 steps | Avg rewards in recent 100 ep: 100.600000
# Episode 202: 200 steps | Avg rewards in recent 100 ep: 102.690000
# Episode 203: 200 steps | Avg rewards in recent 100 ep: 105.560000
# Episode 204: 200 steps | Avg rewards in recent 100 ep: 108.470000
# Episode 205: 200 steps | Avg rewards in recent 100 ep: 111.460000
# Episode 206: 200 steps | Avg rewards in recent 100 ep: 114.610000
# Episode 207: 200 steps | Avg rewards in recent 100 ep: 117.460000
# Episode 208: 200 steps | Avg rewards in recent 100 ep: 121.020000
# Episode 209: 200 steps | Avg rewards in recent 100 ep: 123.900000
# Episode 210: 200 steps | Avg rewards in recent 100 ep: 127.460000
# Episode 211: 200 steps | Avg rewards in recent 100 ep: 130.150000
# Episode 212: 147 steps | Avg rewards in recent 100 ep: 130.580000
# Episode 213: 200 steps | Avg rewards in recent 100 ep: 133.720000
# Episode 214: 200 steps | Avg rewards in recent 100 ep: 136.360000
# Episode 215: 200 steps | Avg rewards in recent 100 ep: 139.010000
# Episode 216: 131 steps | Avg rewards in recent 100 ep: 139.220000
# Episode 217: 200 steps | Avg rewards in recent 100 ep: 141.900000
# Episode 218: 200 steps | Avg rewards in recent 100 ep: 144.190000
# Episode 219: 200 steps | Avg rewards in recent 100 ep: 147.080000
# Episode 220: 200 steps | Avg rewards in recent 100 ep: 150.150000
# Episode 221: 200 steps | Avg rewards in recent 100 ep: 152.870000
# Episode 222: 200 steps | Avg rewards in recent 100 ep: 155.590000
# Episode 223: 173 steps | Avg rewards in recent 100 ep: 156.130000
# Episode 224: 200 steps | Avg rewards in recent 100 ep: 158.210000
# Episode 225: 200 steps | Avg rewards in recent 100 ep: 158.210000
# Episode 226: 200 steps | Avg rewards in recent 100 ep: 160.980000
# Episode 227: 200 steps | Avg rewards in recent 100 ep: 160.980000
# Episode 228: 200 steps | Avg rewards in recent 100 ep: 160.980000
# Episode 229: 200 steps | Avg rewards in recent 100 ep: 164.450000
# Episode 230: 200 steps | Avg rewards in recent 100 ep: 164.450000
# Episode 231: 158 steps | Avg rewards in recent 100 ep: 162.020000
# Episode 232: 200 steps | Avg rewards in recent 100 ep: 162.020000
# Episode 233: 200 steps | Avg rewards in recent 100 ep: 162.060000
# Episode 234: 200 steps | Avg rewards in recent 100 ep: 162.060000
# Episode 235: 200 steps | Avg rewards in recent 100 ep: 164.340000
# Episode 236: 200 steps | Avg rewards in recent 100 ep: 164.340000
# Episode 237: 200 steps | Avg rewards in recent 100 ep: 164.340000
# Episode 238: 180 steps | Avg rewards in recent 100 ep: 162.130000
# Episode 239: 200 steps | Avg rewards in recent 100 ep: 165.740000
# Episode 240: 200 steps | Avg rewards in recent 100 ep: 165.740000
# Episode 241: 200 steps | Avg rewards in recent 100 ep: 165.740000
# Episode 242: 200 steps | Avg rewards in recent 100 ep: 165.740000
# Episode 243: 200 steps | Avg rewards in recent 100 ep: 165.740000
# Episode 244: 200 steps | Avg rewards in recent 100 ep: 165.740000
# Episode 245: 200 steps | Avg rewards in recent 100 ep: 165.740000
# Episode 246: 200 steps | Avg rewards in recent 100 ep: 169.290000
# Episode 247: 200 steps | Avg rewards in recent 100 ep: 169.290000
# Episode 248: 148 steps | Avg rewards in recent 100 ep: 166.760000
# Episode 249: 200 steps | Avg rewards in recent 100 ep: 166.760000
# Episode 250: 200 steps | Avg rewards in recent 100 ep: 166.760000
# Episode 251: 200 steps | Avg rewards in recent 100 ep: 166.760000
# Episode 252: 200 steps | Avg rewards in recent 100 ep: 166.760000
# Episode 253: 137 steps | Avg rewards in recent 100 ep: 164.120000
# Episode 254: 165 steps | Avg rewards in recent 100 ep: 161.760000
# Episode 255: 200 steps | Avg rewards in recent 100 ep: 161.760000
# Episode 256: 200 steps | Avg rewards in recent 100 ep: 161.760000
# Episode 257: 200 steps | Avg rewards in recent 100 ep: 161.760000
# Episode 258: 200 steps | Avg rewards in recent 100 ep: 161.760000
# Episode 259: 160 steps | Avg rewards in recent 100 ep: 159.350000
# Episode 260: 200 steps | Avg rewards in recent 100 ep: 159.350000
# Episode 261: 200 steps | Avg rewards in recent 100 ep: 159.350000
# Episode 262: 200 steps | Avg rewards in recent 100 ep: 159.350000
# Episode 263: 200 steps | Avg rewards in recent 100 ep: 159.350000
# Episode 264: 200 steps | Avg rewards in recent 100 ep: 159.350000
# Episode 265: 200 steps | Avg rewards in recent 100 ep: 159.350000
# Episode 266: 136 steps | Avg rewards in recent 100 ep: 156.700000
# Episode 267: 200 steps | Avg rewards in recent 100 ep: 156.700000
# Episode 268: 155 steps | Avg rewards in recent 100 ep: 154.240000
# Episode 269: 200 steps | Avg rewards in recent 100 ep: 154.240000
# Episode 270: 200 steps | Avg rewards in recent 100 ep: 154.240000
# Episode 271: 200 steps | Avg rewards in recent 100 ep: 154.240000
# Episode 272: 200 steps | Avg rewards in recent 100 ep: 154.240000
# Episode 273: 200 steps | Avg rewards in recent 100 ep: 156.520000
# Episode 274: 200 steps | Avg rewards in recent 100 ep: 156.520000
# Episode 275: 200 steps | Avg rewards in recent 100 ep: 156.520000
# Episode 276: 200 steps | Avg rewards in recent 100 ep: 158.870000
# Episode 277: 200 steps | Avg rewards in recent 100 ep: 158.870000
# Episode 278: 200 steps | Avg rewards in recent 100 ep: 158.870000
# Episode 279: 200 steps | Avg rewards in recent 100 ep: 158.870000
# Episode 280: 147 steps | Avg rewards in recent 100 ep: 158.830000
# Episode 281: 200 steps | Avg rewards in recent 100 ep: 158.830000
# Episode 282: 200 steps | Avg rewards in recent 100 ep: 161.010000
# Episode 283: 200 steps | Avg rewards in recent 100 ep: 161.010000
# Episode 284: 200 steps | Avg rewards in recent 100 ep: 161.010000
# Episode 285: 200 steps | Avg rewards in recent 100 ep: 161.010000
# Episode 286: 200 steps | Avg rewards in recent 100 ep: 161.010000
# Episode 287: 200 steps | Avg rewards in recent 100 ep: 161.010000
# Episode 288: 141 steps | Avg rewards in recent 100 ep: 158.410000
# Episode 289: 200 steps | Avg rewards in recent 100 ep: 160.490000
# Episode 290: 200 steps | Avg rewards in recent 100 ep: 160.490000
# Episode 291: 200 steps | Avg rewards in recent 100 ep: 160.490000
# Episode 292: 142 steps | Avg rewards in recent 100 ep: 157.900000
# Episode 293: 200 steps | Avg rewards in recent 100 ep: 160.660000
# Episode 294: 200 steps | Avg rewards in recent 100 ep: 160.660000
# Episode 295: 200 steps | Avg rewards in recent 100 ep: 162.970000
# Episode 296: 200 steps | Avg rewards in recent 100 ep: 162.970000
# Episode 297: 200 steps | Avg rewards in recent 100 ep: 162.970000
# Episode 298: 200 steps | Avg rewards in recent 100 ep: 162.970000
# Episode 299: 200 steps | Avg rewards in recent 100 ep: 165.060000
# Episode 300: 200 steps | Avg rewards in recent 100 ep: 165.060000
# Episode 301: 200 steps | Avg rewards in recent 100 ep: 165.060000
# Episode 302: 200 steps | Avg rewards in recent 100 ep: 165.060000
# Episode 303: 200 steps | Avg rewards in recent 100 ep: 165.060000
# Episode 304: 200 steps | Avg rewards in recent 100 ep: 165.060000
# Episode 305: 200 steps | Avg rewards in recent 100 ep: 165.060000
# Episode 306: 200 steps | Avg rewards in recent 100 ep: 165.060000
# Episode 307: 200 steps | Avg rewards in recent 100 ep: 165.060000
# Episode 308: 200 steps | Avg rewards in recent 100 ep: 165.060000
# Episode 309: 200 steps | Avg rewards in recent 100 ep: 165.060000
# Episode 310: 200 steps | Avg rewards in recent 100 ep: 165.060000
# Episode 311: 200 steps | Avg rewards in recent 100 ep: 165.060000
# Episode 312: 200 steps | Avg rewards in recent 100 ep: 167.600000
# Episode 313: 200 steps | Avg rewards in recent 100 ep: 167.600000
# Episode 314: 200 steps | Avg rewards in recent 100 ep: 167.600000
# Episode 315: 200 steps | Avg rewards in recent 100 ep: 167.600000
# Episode 316: 200 steps | Avg rewards in recent 100 ep: 170.300000
# Episode 317: 200 steps | Avg rewards in recent 100 ep: 170.300000
# Episode 318: 200 steps | Avg rewards in recent 100 ep: 170.300000
# Episode 319: 200 steps | Avg rewards in recent 100 ep: 170.300000
# Episode 320: 200 steps | Avg rewards in recent 100 ep: 170.300000
# Episode 321: 200 steps | Avg rewards in recent 100 ep: 170.300000
# Episode 322: 200 steps | Avg rewards in recent 100 ep: 170.300000
# Episode 323: 200 steps | Avg rewards in recent 100 ep: 172.580000
# Episode 324: 200 steps | Avg rewards in recent 100 ep: 172.580000
# Episode 325: 200 steps | Avg rewards in recent 100 ep: 172.580000
# Episode 326: 200 steps | Avg rewards in recent 100 ep: 172.580000
# Episode 327: 200 steps | Avg rewards in recent 100 ep: 172.580000
# Episode 328: 200 steps | Avg rewards in recent 100 ep: 172.580000
# Episode 329: 200 steps | Avg rewards in recent 100 ep: 172.580000
# Episode 330: 200 steps | Avg rewards in recent 100 ep: 172.580000
# Episode 331: 200 steps | Avg rewards in recent 100 ep: 175.010000
# Episode 332: 200 steps | Avg rewards in recent 100 ep: 175.010000
# Episode 333: 200 steps | Avg rewards in recent 100 ep: 175.010000
# Episode 334: 200 steps | Avg rewards in recent 100 ep: 175.010000
# Episode 335: 96 steps | Avg rewards in recent 100 ep: 171.960000
# Episode 336: 200 steps | Avg rewards in recent 100 ep: 171.960000
# Episode 337: 200 steps | Avg rewards in recent 100 ep: 171.960000
# Episode 338: 200 steps | Avg rewards in recent 100 ep: 174.170000
# Episode 339: 200 steps | Avg rewards in recent 100 ep: 174.170000
# Episode 340: 200 steps | Avg rewards in recent 100 ep: 174.170000
# Episode 341: 200 steps | Avg rewards in recent 100 ep: 174.170000
# Episode 342: 200 steps | Avg rewards in recent 100 ep: 174.170000
# Episode 343: 200 steps | Avg rewards in recent 100 ep: 174.170000
# Episode 344: 200 steps | Avg rewards in recent 100 ep: 174.170000
# Episode 345: 200 steps | Avg rewards in recent 100 ep: 174.170000
# Episode 346: 200 steps | Avg rewards in recent 100 ep: 174.170000
# Episode 347: 200 steps | Avg rewards in recent 100 ep: 174.170000
# Episode 348: 200 steps | Avg rewards in recent 100 ep: 176.700000
# Episode 349: 200 steps | Avg rewards in recent 100 ep: 176.700000
# Episode 350: 200 steps | Avg rewards in recent 100 ep: 176.700000
# Episode 351: 200 steps | Avg rewards in recent 100 ep: 176.700000
# Episode 352: 200 steps | Avg rewards in recent 100 ep: 176.700000
# Episode 353: 200 steps | Avg rewards in recent 100 ep: 179.340000
# Episode 354: 200 steps | Avg rewards in recent 100 ep: 181.700000
# Episode 355: 200 steps | Avg rewards in recent 100 ep: 181.700000
# Episode 356: 200 steps | Avg rewards in recent 100 ep: 181.700000
# Episode 357: 200 steps | Avg rewards in recent 100 ep: 181.700000
# Episode 358: 200 steps | Avg rewards in recent 100 ep: 181.700000
# Episode 359: 200 steps | Avg rewards in recent 100 ep: 184.110000
# Episode 360: 200 steps | Avg rewards in recent 100 ep: 184.110000
# Episode 361: 200 steps | Avg rewards in recent 100 ep: 184.110000
# Episode 362: 200 steps | Avg rewards in recent 100 ep: 184.110000
# Episode 363: 191 steps | Avg rewards in recent 100 ep: 182.010000
# Episode 364: 200 steps | Avg rewards in recent 100 ep: 182.010000
# Episode 365: 200 steps | Avg rewards in recent 100 ep: 182.010000
# Episode 366: 200 steps | Avg rewards in recent 100 ep: 184.660000
# Episode 367: 200 steps | Avg rewards in recent 100 ep: 184.660000
# Episode 368: 200 steps | Avg rewards in recent 100 ep: 187.120000
# Episode 369: 200 steps | Avg rewards in recent 100 ep: 187.120000
# Episode 370: 150 steps | Avg rewards in recent 100 ep: 184.610000
# Episode 371: 200 steps | Avg rewards in recent 100 ep: 184.610000
# Episode 372: 200 steps | Avg rewards in recent 100 ep: 184.610000
# Episode 373: 200 steps | Avg rewards in recent 100 ep: 184.610000
# Episode 374: 200 steps | Avg rewards in recent 100 ep: 184.610000
# Episode 375: 200 steps | Avg rewards in recent 100 ep: 184.610000
# Episode 376: 200 steps | Avg rewards in recent 100 ep: 184.610000
# Episode 377: 200 steps | Avg rewards in recent 100 ep: 184.610000
# Episode 378: 200 steps | Avg rewards in recent 100 ep: 184.610000
# Episode 379: 200 steps | Avg rewards in recent 100 ep: 184.610000
# Episode 380: 200 steps | Avg rewards in recent 100 ep: 187.150000
# Episode 381: 200 steps | Avg rewards in recent 100 ep: 187.150000
# Episode 382: 200 steps | Avg rewards in recent 100 ep: 187.150000
# Episode 383: 200 steps | Avg rewards in recent 100 ep: 187.150000
# Episode 384: 200 steps | Avg rewards in recent 100 ep: 187.150000
# Episode 385: 200 steps | Avg rewards in recent 100 ep: 187.150000
# Episode 386: 200 steps | Avg rewards in recent 100 ep: 187.150000
# Episode 387: 200 steps | Avg rewards in recent 100 ep: 187.150000
# Episode 388: 200 steps | Avg rewards in recent 100 ep: 189.750000
# Episode 389: 200 steps | Avg rewards in recent 100 ep: 189.750000
# Episode 390: 200 steps | Avg rewards in recent 100 ep: 189.750000
# Episode 391: 200 steps | Avg rewards in recent 100 ep: 189.750000
# Episode 392: 200 steps | Avg rewards in recent 100 ep: 192.340000
# Episode 393: 200 steps | Avg rewards in recent 100 ep: 192.340000
# Episode 394: 200 steps | Avg rewards in recent 100 ep: 192.340000
# Episode 395: 200 steps | Avg rewards in recent 100 ep: 192.340000
# Episode 396: 200 steps | Avg rewards in recent 100 ep: 192.340000
# Episode 397: 200 steps | Avg rewards in recent 100 ep: 192.340000
# Episode 398: 200 steps | Avg rewards in recent 100 ep: 192.340000
# Episode 399: 200 steps | Avg rewards in recent 100 ep: 192.340000
# Episode 400: 200 steps | Avg rewards in recent 100 ep: 192.340000
# Episode 401: 200 steps | Avg rewards in recent 100 ep: 192.340000
# Episode 402: 200 steps | Avg rewards in recent 100 ep: 192.340000
# Episode 403: 200 steps | Avg rewards in recent 100 ep: 192.340000
# Episode 404: 151 steps | Avg rewards in recent 100 ep: 189.840000
# Episode 405: 200 steps | Avg rewards in recent 100 ep: 189.840000
# Episode 406: 183 steps | Avg rewards in recent 100 ep: 187.660000
# Episode 407: 200 steps | Avg rewards in recent 100 ep: 187.660000
# Episode 408: 200 steps | Avg rewards in recent 100 ep: 187.660000
# Episode 409: 200 steps | Avg rewards in recent 100 ep: 187.660000
# Episode 410: 200 steps | Avg rewards in recent 100 ep: 187.660000
# Episode 411: 200 steps | Avg rewards in recent 100 ep: 187.660000
# Episode 412: 200 steps | Avg rewards in recent 100 ep: 187.660000
# Episode 413: 200 steps | Avg rewards in recent 100 ep: 187.660000
# Episode 414: 200 steps | Avg rewards in recent 100 ep: 187.660000
# Episode 415: 200 steps | Avg rewards in recent 100 ep: 187.660000
# Episode 416: 200 steps | Avg rewards in recent 100 ep: 187.660000
# Episode 417: 200 steps | Avg rewards in recent 100 ep: 187.660000
# Episode 418: 200 steps | Avg rewards in recent 100 ep: 187.660000
# Episode 419: 200 steps | Avg rewards in recent 100 ep: 187.660000
# Episode 420: 200 steps | Avg rewards in recent 100 ep: 187.660000
# Episode 421: 200 steps | Avg rewards in recent 100 ep: 187.660000
# Episode 422: 200 steps | Avg rewards in recent 100 ep: 187.660000
# Episode 423: 200 steps | Avg rewards in recent 100 ep: 187.660000
# Episode 424: 200 steps | Avg rewards in recent 100 ep: 187.660000
# Episode 425: 151 steps | Avg rewards in recent 100 ep: 185.160000
# Episode 426: 200 steps | Avg rewards in recent 100 ep: 185.160000
# Episode 427: 200 steps | Avg rewards in recent 100 ep: 185.160000
# Episode 428: 180 steps | Avg rewards in recent 100 ep: 182.950000
# Episode 429: 19 steps | Avg rewards in recent 100 ep: 179.130000
# Episode 430: 151 steps | Avg rewards in recent 100 ep: 176.630000
# Episode 431: 108 steps | Avg rewards in recent 100 ep: 173.700000
# Episode 432: 200 steps | Avg rewards in recent 100 ep: 173.700000
# Episode 433: 200 steps | Avg rewards in recent 100 ep: 173.700000
# Episode 434: 200 steps | Avg rewards in recent 100 ep: 173.700000
# Episode 435: 154 steps | Avg rewards in recent 100 ep: 174.280000
# Episode 436: 200 steps | Avg rewards in recent 100 ep: 174.280000
# Episode 437: 200 steps | Avg rewards in recent 100 ep: 174.280000
# Episode 438: 200 steps | Avg rewards in recent 100 ep: 174.280000
# Episode 439: 200 steps | Avg rewards in recent 100 ep: 174.280000
# Episode 440: 200 steps | Avg rewards in recent 100 ep: 174.280000
# Episode 441: 170 steps | Avg rewards in recent 100 ep: 171.970000
# Episode 442: 200 steps | Avg rewards in recent 100 ep: 171.970000
# Episode 443: 200 steps | Avg rewards in recent 100 ep: 171.970000
# Episode 444: 200 steps | Avg rewards in recent 100 ep: 171.970000
# Episode 445: 200 steps | Avg rewards in recent 100 ep: 171.970000
# Episode 446: 200 steps | Avg rewards in recent 100 ep: 171.970000
# Episode 447: 200 steps | Avg rewards in recent 100 ep: 171.970000
# Episode 448: 140 steps | Avg rewards in recent 100 ep: 169.360000
# Episode 449: 200 steps | Avg rewards in recent 100 ep: 169.360000
# Episode 450: 200 steps | Avg rewards in recent 100 ep: 169.360000
# Episode 451: 200 steps | Avg rewards in recent 100 ep: 169.360000
# Episode 452: 200 steps | Avg rewards in recent 100 ep: 169.360000
# Episode 453: 200 steps | Avg rewards in recent 100 ep: 169.360000
# Episode 454: 150 steps | Avg rewards in recent 100 ep: 166.850000
# Episode 455: 200 steps | Avg rewards in recent 100 ep: 166.850000
# Episode 456: 185 steps | Avg rewards in recent 100 ep: 164.690000
# Episode 457: 17 steps | Avg rewards in recent 100 ep: 160.850000
# Episode 458: 137 steps | Avg rewards in recent 100 ep: 158.210000
# Episode 459: 117 steps | Avg rewards in recent 100 ep: 155.370000
# Episode 460: 179 steps | Avg rewards in recent 100 ep: 153.150000
# Episode 461: 164 steps | Avg rewards in recent 100 ep: 150.780000
# Episode 462: 200 steps | Avg rewards in recent 100 ep: 150.780000
# Episode 463: 139 steps | Avg rewards in recent 100 ep: 150.260000
# Episode 464: 24 steps | Avg rewards in recent 100 ep: 146.490000
# Episode 465: 148 steps | Avg rewards in recent 100 ep: 143.960000
# Episode 466: 199 steps | Avg rewards in recent 100 ep: 143.950000
# Episode 467: 171 steps | Avg rewards in recent 100 ep: 141.650000
# Episode 468: 199 steps | Avg rewards in recent 100 ep: 141.640000
# Episode 469: 200 steps | Avg rewards in recent 100 ep: 141.640000
# Episode 470: 133 steps | Avg rewards in recent 100 ep: 141.470000
# Episode 471: 138 steps | Avg rewards in recent 100 ep: 138.840000
# Episode 472: 132 steps | Avg rewards in recent 100 ep: 136.150000
# Episode 473: 151 steps | Avg rewards in recent 100 ep: 133.650000
# Episode 474: 200 steps | Avg rewards in recent 100 ep: 133.650000
# Episode 475: 200 steps | Avg rewards in recent 100 ep: 133.650000
# Episode 476: 193 steps | Avg rewards in recent 100 ep: 131.570000
# Episode 477: 200 steps | Avg rewards in recent 100 ep: 131.570000
# Episode 478: 169 steps | Avg rewards in recent 100 ep: 129.250000
# Episode 479: 192 steps | Avg rewards in recent 100 ep: 127.160000
# Episode 480: 169 steps | Avg rewards in recent 100 ep: 124.840000
# Episode 481: 184 steps | Avg rewards in recent 100 ep: 122.670000
# Episode 482: 200 steps | Avg rewards in recent 100 ep: 122.670000
# Episode 483: 198 steps | Avg rewards in recent 100 ep: 122.650000
# Episode 484: 167 steps | Avg rewards in recent 100 ep: 120.310000
# Episode 485: 157 steps | Avg rewards in recent 100 ep: 117.870000
# Episode 486: 200 steps | Avg rewards in recent 100 ep: 117.870000
# Episode 487: 200 steps | Avg rewards in recent 100 ep: 117.870000
# Episode 488: 200 steps | Avg rewards in recent 100 ep: 117.870000
# Episode 489: 200 steps | Avg rewards in recent 100 ep: 117.870000
# Episode 490: 200 steps | Avg rewards in recent 100 ep: 117.870000
# Episode 491: 200 steps | Avg rewards in recent 100 ep: 117.870000
# Episode 492: 200 steps | Avg rewards in recent 100 ep: 117.870000
# Episode 493: 200 steps | Avg rewards in recent 100 ep: 117.870000
# Episode 494: 200 steps | Avg rewards in recent 100 ep: 117.870000
# Episode 495: 200 steps | Avg rewards in recent 100 ep: 117.870000
# Episode 496: 200 steps | Avg rewards in recent 100 ep: 117.870000
# Episode 497: 200 steps | Avg rewards in recent 100 ep: 117.870000
# Episode 498: 200 steps | Avg rewards in recent 100 ep: 117.870000
# Episode 499: 200 steps | Avg rewards in recent 100 ep: 117.870000
# Episode 500: 200 steps | Avg rewards in recent 100 ep: 117.870000
# Episode 501: 200 steps | Avg rewards in recent 100 ep: 117.870000
# Episode 502: 200 steps | Avg rewards in recent 100 ep: 117.870000
# Episode 503: 200 steps | Avg rewards in recent 100 ep: 117.870000
# Episode 504: 200 steps | Avg rewards in recent 100 ep: 120.370000
# Episode 505: 200 steps | Avg rewards in recent 100 ep: 120.370000
# Episode 506: 200 steps | Avg rewards in recent 100 ep: 122.550000
# Episode 507: 200 steps | Avg rewards in recent 100 ep: 122.550000
# Episode 508: 200 steps | Avg rewards in recent 100 ep: 122.550000
# Episode 509: 200 steps | Avg rewards in recent 100 ep: 122.550000
# Episode 510: 200 steps | Avg rewards in recent 100 ep: 122.550000
# Episode 511: 200 steps | Avg rewards in recent 100 ep: 122.550000
# Episode 512: 200 steps | Avg rewards in recent 100 ep: 122.550000
# Episode 513: 200 steps | Avg rewards in recent 100 ep: 122.550000
# Episode 514: 200 steps | Avg rewards in recent 100 ep: 122.550000
# Episode 515: 200 steps | Avg rewards in recent 100 ep: 122.550000
# Episode 516: 200 steps | Avg rewards in recent 100 ep: 122.550000
# Episode 517: 200 steps | Avg rewards in recent 100 ep: 122.550000
# Episode 518: 200 steps | Avg rewards in recent 100 ep: 122.550000
# Episode 519: 200 steps | Avg rewards in recent 100 ep: 122.550000
# Episode 520: 200 steps | Avg rewards in recent 100 ep: 122.550000
# Episode 521: 200 steps | Avg rewards in recent 100 ep: 122.550000
# Episode 522: 200 steps | Avg rewards in recent 100 ep: 122.550000
# Episode 523: 200 steps | Avg rewards in recent 100 ep: 122.550000
# Episode 524: 200 steps | Avg rewards in recent 100 ep: 122.550000
# Episode 525: 200 steps | Avg rewards in recent 100 ep: 125.050000
# Episode 526: 200 steps | Avg rewards in recent 100 ep: 125.050000
# Episode 527: 200 steps | Avg rewards in recent 100 ep: 125.050000
# Episode 528: 200 steps | Avg rewards in recent 100 ep: 127.260000
# Episode 529: 200 steps | Avg rewards in recent 100 ep: 131.080000
# Episode 530: 200 steps | Avg rewards in recent 100 ep: 133.580000
# Episode 531: 200 steps | Avg rewards in recent 100 ep: 136.510000
# Episode 532: 200 steps | Avg rewards in recent 100 ep: 136.510000
# Episode 533: 200 steps | Avg rewards in recent 100 ep: 136.510000
# Episode 534: 200 steps | Avg rewards in recent 100 ep: 136.510000
# Episode 535: 200 steps | Avg rewards in recent 100 ep: 138.980000
# Episode 536: 200 steps | Avg rewards in recent 100 ep: 138.980000
# Episode 537: 200 steps | Avg rewards in recent 100 ep: 138.980000
# Episode 538: 200 steps | Avg rewards in recent 100 ep: 138.980000
# Episode 539: 200 steps | Avg rewards in recent 100 ep: 138.980000
# Episode 540: 200 steps | Avg rewards in recent 100 ep: 138.980000
# Episode 541: 200 steps | Avg rewards in recent 100 ep: 141.290000
# Episode 542: 200 steps | Avg rewards in recent 100 ep: 141.290000
# Episode 543: 200 steps | Avg rewards in recent 100 ep: 141.290000
# Episode 544: 200 steps | Avg rewards in recent 100 ep: 141.290000
# Episode 545: 200 steps | Avg rewards in recent 100 ep: 141.290000
# Episode 546: 200 steps | Avg rewards in recent 100 ep: 141.290000
# Episode 547: 200 steps | Avg rewards in recent 100 ep: 141.290000
# Episode 548: 200 steps | Avg rewards in recent 100 ep: 143.900000
# Episode 549: 200 steps | Avg rewards in recent 100 ep: 143.900000
# Episode 550: 200 steps | Avg rewards in recent 100 ep: 143.900000
# Episode 551: 200 steps | Avg rewards in recent 100 ep: 143.900000
# Episode 552: 200 steps | Avg rewards in recent 100 ep: 143.900000
# Episode 553: 200 steps | Avg rewards in recent 100 ep: 143.900000
# Episode 554: 200 steps | Avg rewards in recent 100 ep: 146.410000
# Episode 555: 200 steps | Avg rewards in recent 100 ep: 146.410000
# Episode 556: 200 steps | Avg rewards in recent 100 ep: 148.570000
# Episode 557: 200 steps | Avg rewards in recent 100 ep: 152.410000
# Episode 558: 200 steps | Avg rewards in recent 100 ep: 155.050000
# Episode 559: 200 steps | Avg rewards in recent 100 ep: 157.890000
# Episode 560: 200 steps | Avg rewards in recent 100 ep: 160.110000
# Episode 561: 200 steps | Avg rewards in recent 100 ep: 162.480000
# Episode 562: 200 steps | Avg rewards in recent 100 ep: 162.480000
# Episode 563: 200 steps | Avg rewards in recent 100 ep: 165.100000
# Episode 564: 200 steps | Avg rewards in recent 100 ep: 168.870000
# Episode 565: 200 steps | Avg rewards in recent 100 ep: 171.400000
# Episode 566: 200 steps | Avg rewards in recent 100 ep: 171.410000
# Episode 567: 200 steps | Avg rewards in recent 100 ep: 173.710000
# Episode 568: 200 steps | Avg rewards in recent 100 ep: 173.720000
# Episode 569: 200 steps | Avg rewards in recent 100 ep: 173.720000
# Episode 570: 200 steps | Avg rewards in recent 100 ep: 176.400000
# Episode 571: 200 steps | Avg rewards in recent 100 ep: 179.030000
# Episode 572: 200 steps | Avg rewards in recent 100 ep: 181.720000
# Episode 573: 200 steps | Avg rewards in recent 100 ep: 184.220000
# Episode 574: 200 steps | Avg rewards in recent 100 ep: 184.220000
# Episode 575: 200 steps | Avg rewards in recent 100 ep: 184.220000
# Episode 576: 200 steps | Avg rewards in recent 100 ep: 186.300000
# Episode 577: 200 steps | Avg rewards in recent 100 ep: 186.300000
# Episode 578: 200 steps | Avg rewards in recent 100 ep: 188.620000
# Episode 579: 200 steps | Avg rewards in recent 100 ep: 190.710000
# Episode 580: 200 steps | Avg rewards in recent 100 ep: 193.030000
# Episode 581: 200 steps | Avg rewards in recent 100 ep: 195.200000
# Success in episode 581
# Episode 582: 200 steps | Avg rewards in recent 100 ep: 195.200000
